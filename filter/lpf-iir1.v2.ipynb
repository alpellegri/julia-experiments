# %% [markdown]
# $$ y[n] = b_0x[n] + a_1y[n-1] $$
#
# where,
# $$ b_0 = b_1 $$
# $$ b_0 + b_1 + a_1 = 1 $$
#
# therefore,
# $$ a_1 = \alpha $$
# $$ b_0 = {1-\alpha} $$
#
#
# $$ H(z) = \frac{1-\alpha}{1-\alpha z^{-1}} $$
#
# $$ H(e^{j\omega}) = \frac{1-\alpha}{1-\alpha e^{-j\omega}} $$
#
# $$ |H(j\omega)|^2 = \frac{1-2\alpha+\alpha^2}{(1-\alpha e^{-j\omega}){(1-\alpha e^{-j\omega})}^*} $$
#
# using Eulero formula:
#
# $$ e^{j\omega} = cos\omega + jsin\omega $$
#
# therefore:
#
# $$ |H(j\omega)|^2 = \frac{1-2\alpha+\alpha^2}{(1-\alpha cos\omega-j\alpha sin\omega)(1-\alpha cos\omega+j\alpha sin\omega)} $$
#
# $$ |H(j\omega)|^2 = \frac{1-2\alpha+\alpha^2}{1-2\alpha cos\omega+\alpha cos^2\omega} $$
#
# cut-off frequency:
#
# $$ \frac{1}{2} = \frac{1-2\alpha+\alpha^2}{1+\alpha^2-2\alpha cos\omega} $$
#
# $$ 1+\alpha^2-2\alpha cos\omega = 2-4\alpha+2\alpha^2 $$
#
# $$ \alpha^2 - (4-2cos\omega)\alpha + 1 = 0 $$
#
# solving the quadratic equation in $\alpha$
#
# recall the roots of a quadratic equation:
#
# $$ ax^2+bx+c=0 $$
#
# has roots on:
#
# $$ x = \frac{-b\pm\sqrt{b^2-4ac}}{2a} $$
#
# therefore:
#
# $$ \alpha = \frac{2(2-cos\omega)\pm\sqrt{(4-2cos\omega)^2-4}}{2} $$
#
# $$ \alpha = \frac{2(2-cos\omega)\pm\sqrt{12+4cos^2\omega -16cos\omega}}{2} $$

# %% [markdown]
# first order IIR filter:
#
# $$ y[n] = b_0x[n] + b_1x[n-1] + a_0y[n-1] $$
#
# where,
# $$ b_0 = b_1 $$
# $$ b_0 + b_1 + a_0 = 1 $$
#
# therefore,
# $$ a_0 = \alpha $$
# $$ b_0 = b_1 = \frac{1-\alpha}{2} $$
#
# $$ H(z) = {\frac{1-\alpha}{2}}{\frac{1+z^{-1}}{1-\alpha z^{-1}}} $$
#
# substituting
# $$ z = e^{j\omega} $$
#
# $$ H(e^{j\omega}) = {\frac{1-\alpha}{2}}{\frac{1+e^{-j\omega}}{1-\alpha e^{-j\omega}}} $$
#
# $$ |H(e^{j\omega})|^2 = {\frac{(1-\alpha)^2}{2^2}} {\frac{(1+e^{-j\omega})(1+e^{-j\omega})^*}{(1-\alpha e^{-j\omega}){(1-\alpha e^{-j\omega})}^*}} $$
#
# using Eulero formula:
#
# $$ e^{j\omega} = cos\omega + jsin\omega $$
#
# therefore:
#
# $$ |H(j\omega)|^2 = {\frac{(1-\alpha)^2}{4}} \frac{(1+cos\omega-jsin\omega)(1+cos\omega+jsin\omega)}{(1-\alpha cos\omega-j\alpha sin\omega)(1-\alpha cos\omega+j\alpha sin\omega)} $$
#
# solving numerator:
#
# $$ (1+cos\omega-jsin\omega)(1+cos\omega+jsin\omega) = 1 + 2cos\omega + cos^2\omega + sin^2\omega - jsin\omega(1+cos\omega) + (1+cos\omega)jsin\omega $$
#
# $$ cos^2\omega + sin^2\omega = 1 $$
#
# $$ (1+cos\omega-jsin\omega)(1+cos\omega+jsin\omega) = 2(1+cos\omega) $$
#
# solving denominator:
#
# $$ (1-\alpha cos\omega-j\alpha sin\omega)(1-\alpha cos\omega+j\alpha sin\omega) = 1 - 2\alpha cos\omega + \alpha^2cos^2\omega - \alpha^2sin^2\omega + j\alpha sin\omega(1+\alpha cos\omega) + (1+\alpha cos\omega)j\alpha sin\omega $$
#
# $$ (1-\alpha cos\omega-j\alpha sin\omega)(1-\alpha cos\omega+j\alpha sin\omega) = 1 - 2\alpha cos\omega + \alpha^2 $$
#
# $$ |H(j\omega)|^2 = {\frac{(1-\alpha)^2}{4}} \frac{2(1+cos\omega)}{1 - 2\alpha cos\omega + \alpha^2} $$
#
# $$ |H(j\omega)|^2 = {\frac{(1-\alpha)^2}{2}} \frac{1+cos\omega}{1 - 2\alpha cos\omega + \alpha^2} $$
#
# cut-off frequency:
#
# $$ \frac{1}{2} = |H(j\omega)|^2 $$
#
# $$ \frac{1}{2} = {\frac{(1-\alpha)^2}{2}} \frac{1+cos\omega}{1 - 2\alpha cos\omega + \alpha^2} $$
#
# $$ 1 = (1-\alpha)^2 \frac{1+cos\omega}{1 - 2\alpha cos\omega + \alpha^2} $$
#
# $$ 1 - 2\alpha cos\omega + \alpha^2 = (1-2\alpha+\alpha^2)(1 + cos\omega) $$
#
# $$ 1 - 2\alpha cos\omega + \alpha^2 = 1+cos\omega - 2\alpha - 2\alpha cos\omega +\alpha^2 + \alpha^2 cos\omega $$
#
# $$ 0 = cos\omega - 2\alpha + \alpha^2 cos\omega $$
#
# solving the quadratic equation in $\alpha$
#
# recall the roots of a quadratic equation:
#
# $$ ax^2+bx+c=0 $$
#
# has roots on:
#
# $$ x = \frac{-b\pm\sqrt{b^2-4ac}}{2a} $$
#
# therefore:
#
# $$ \alpha = \frac{2\pm\sqrt{4-4cos^2\omega}}{2cos\omega} $$
#
# $$ \alpha = \frac{2\pm\sqrt{4sin^2\omega}}{2cos\omega} $$
#
# $$ \alpha = \frac{1\pm{sin\omega}}{cos\omega} $$
#
# $$ \alpha = \frac{1-{sin\omega}}{cos\omega} $$

# %%
using PyPlot

wc = 0:.1:pi

alpha = (4-2*cos.(wc) .- sqrt(12 .+ 4*cos.(wc).^2 .- 16*cos.(wc)))/2
plot(alpha, wc)

alpha = (1-sin.(wc))./cos.(wc)
plot(alpha, wc)
# Out:
# ┌ Info: Installing matplotlib via the Conda matplotlib package...
# └ @ PyCall C:\Users\aless\.julia\packages\PyCall\ttONZ\src\PyCall.jl:705
# ┌ Info: Running `conda install -y matplotlib` in root environment
# └ @ Conda C:\Users\aless\.julia\packages\Conda\kLXeC\src\Conda.jl:112
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
# InitError: PyError (PyImport_ImportModule
#
# The Python package matplotlib could not be found by pyimport. Usually this means
# that you did not install matplotlib in the Python version being used by PyCall.
#
# PyCall is currently configured to use the Julia-specific Python distribution
# installed by the Conda.jl package.  To install the matplotlib module, you can
# use `pyimport_conda("matplotlib", PKG)`, where PKG is the Anaconda
# package the contains the module matplotlib, or alternatively you can use the
# Conda package directly (via `using Conda` followed by `Conda.add` etcetera).
#
# ...

# %%
using PyPlot

# sampling frequency
fs = 10000

# cut-off frequencies
fc = 1:10:fs/2

# cut-off angles
wc = 2pi*fc/fs

alpha = (4-2*cos(wc) .- sqrt(12 .+ 4*cos(wc).^2 .- 16*cos(wc)))/2
plot(alpha, fc)

alpha = (1-sin(wc))./cos(wc)
plot(alpha, fc)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f20b4a0fc90>

# %%
using PyPlot
using DSP

fs = 10000
w = 0:0.01:pi # variables can have Unicode names! This is typed in the notebook as \omega + tab.

# fig = figure()
xlabel("Frequency [Hz]")
ylabel("Gain [dB]")

fc = 2500
wc = 2pi*fc/fs

alpha = (4-2*cos(wc) - sqrt(12 + 4*cos(wc)^2 - 16*cos(wc)))/2
println("$alpha, $wc")

b = [(1 - alpha)]
a = [1, -alpha]
filter = PolynomialRatio(b,a)

# Let's take a look at the filter response now
H = freqz(filter, w)
plot(fs/2*w/pi, 20*log10(abs(H)))

alpha = (1-sin(wc))/cos(wc)
println("$alpha, $wc")

b = [(1 - alpha)/2,(1 - alpha)/2]
a = [1, -alpha]
filter = PolynomialRatio(b,a)

# Let's take a look at the filter response now
H = freqz(filter, w)
plot(fs/2*w/pi, 20*log10(abs(H)))
ylim(-3,1)
# Out:
# ┌ Info: Precompiling PyPlot [d330b81b-6aea-500a-939a-2ce795aea3ee]
# └ @ Base loading.jl:1192
# ERROR: LoadError: LoadError: PyCall not properly installed. Please run Pkg.build("PyCall")
# Stacktrace:
#  [1] error(::String) at .\error.jl:33
#  [2] top-level scope at C:\Users\aless\.julia\packages\PyCall\ttONZ\src\startup.jl:44 [inlined]
#  [3] top-level scope at .\none:0
#  [4] include at .\boot.jl:317 [inlined]
#  [5] include_relative(::Module, ::String) at .\loading.jl:1044
#  [6] include at .\sysimg.jl:29 [inlined]
#  [7] include(::String) at C:\Users\aless\.julia\packages\PyCall\ttONZ\src\PyCall.jl:1
#  [8] top-level scope at none:0
#  [9] include at .\boot.jl:317 [inlined]
#  [10] include_relative(::Module, ::String) at .\loading.jl:1044
#  [11] include(::Module, ::String) at .\sysimg.jl:29
#  [12] top-level scope at none:2
#  [13] eval at .\boot.jl:319 [inlined]
#  [14] eval(::Expr) at .\client.jl:393
#  [15] top-level scope at .\none:3
# ...

# %%
using Interact
using PyPlot
using DSP

fs= 10000
w = 0:0.01:pi # variables can have Unicode names! This is typed in the notebook as \omega + tab.

fig = figure()
xlabel("Frequency [Hz]")
ylabel("Gain [dB]")
@manipulate for fc = 1:50:fs/2
    withfig(fig) do

        wc = 2pi*fc/fs

        alpha = (4-2*cos(wc) - sqrt(12 + 4*cos(wc)^2 - 16*cos(wc)))/2
        b = [(1 - alpha)]
        a = [1, -alpha]
        filter = PolynomialRatio(b,a)

        # Let's take a look at the filter response now
        H = freqz(filter, w)
        plot(fs/2*w/pi, 20*log10(abs(H)))

        alpha = (1-sin(wc))/cos(wc)
        b = [(1 - alpha)/2,(1 - alpha)/2]
        a = [1, -alpha]
        filter = PolynomialRatio(b,a)

        # Let's take a look at the filter response now
        H = freqz(filter, w)
        plot(fs/2*w/pi, 20*log10(abs(H)))
        ylim(-30,1)
    end
end

# %%
using Interact
using PyPlot
using DSP

fs= 10000
w = 0:0.01:pi # variables can have Unicode names! This is typed in the notebook as \omega + tab.

lut(x) = 1-exp(log(1/4)/(x+1))

fig = figure()
xlabel("Frequency [Hz]")
ylabel("Gain [dB]")
@manipulate for fc = 1:10:(fs/2)/4
    withfig(fig) do

        beta = lut(10000/fc)
        b = [beta]
        a = [1, -(1-beta)]
        filter = PolynomialRatio(b,a)

        # Let's take a look at the filter response now
        H = freqz(filter, w)
        plot(fs/2*w/pi, 20*log10(abs(H)))

        wc = (2pi*fc/fs)/6.0

        alpha = (4-2*cos(wc) - sqrt(12 + 4*cos(wc)^2 - 16*cos(wc)))/2
        b = [(1 - alpha)]
        a = [1, -alpha]
        filter = PolynomialRatio(b,a)

        # Let's take a look at the filter response now
        H = freqz(filter, w)
        plot(fs/2*w/pi, 20*log10(abs(H)))

        xlim(0,fs/4); ylim(-3,1)
        legend([10000/fc])
    end
end
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-3048904833829537413\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-3319553474699792958\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio/main\"]) {\n            // Extension already loaded.\n            cons
# ...

# %%
fs = 10000
fc = 1:500:fs/2
lut(x) = 1-exp(log(1/4)./(x+1))

yl = lut(10000./fc)
# Out:
# 10-element Array{Float64,1}:
#  0.000138606
#  0.0639999
#  0.11851
#  0.165503
#  0.206376
#  0.242209
#  0.273848
#  0.301965
#  0.327097
#  0.349683

# %%
p = 1:1:10
lut(x) = 1-exp(log(1/4)./(x+1))
lut(p)

fs= 10000
w = 0:0.001:pi/25 # variables can have Unicode names! This is typed in the notebook as \omega + tab.

# 1 ms period
beta = lut(10)
b = [beta]
a = [1, -(1-beta)]
filter = PolynomialRatio(b,a)

# Let's take a look at the filter response now
H = freqz(filter, w)
plot(fs/2*w/pi, 20*log10(abs(H)))

# 2 ms period
beta = lut(20)
b = [beta]
a = [1, -(1-beta)]
filter = PolynomialRatio(b,a)

# Let's take a look at the filter response now
H = freqz(filter, w)
plot(fs/2*w/pi, 20*log10(abs(H)))
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f20b4439910>

# %%
using Interact
using PyPlot
using DSP

fs= 10000
Ts = 1/fs
w = 0:0.01:pi # variables can have Unicode names! This is typed in the notebook as \omega + tab.

f = 1500
t = 0:Ts:10/f
y = sin(2pi*f*t)

fig = figure()
xlabel("Frequency [Hz]")
ylabel("Gain [dB]")
@manipulate for fc = 1:10:fs/2
    withfig(fig) do

        wc = 2pi*fc/fs

        alpha = (4-2*cos(wc) - sqrt(12 + 4*cos(wc)^2 - 16*cos(wc)))/2
        b = [(1 - alpha)]
        a = [1, -alpha]
        filter = PolynomialRatio(b,a)
        yf = filt(filter, y)

        # Let's take a look at the filter response now
        H = freqz(filter, w)
        plot(t, yf)

        alpha = (1-sin(wc))/cos(wc)
        b = [(1 - alpha)/2,(1 - alpha)/2]
        a = [1, -alpha]
        filter = PolynomialRatio(b,a)
        yf = filt(filter, y)

        # Let's take a look at the filter response now
        H = freqz(filter, w)
        plot(t, yf)
    end
end
# Out:
# (div
# ...

# %%
using PyPlot

x = -pi:.001:pi

j = abs(((abs(x)/(pi/2))%4)-2)-1
plot(x,j,color="blue")
j = -asin((abs(x)/(pi/2)-1))/(pi/2)
plot(x,j,color="green")
gcf()
;
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fe0441c1fd0>)

# %%
x = -pi:.0001:pi
# x = linspace(0,200,10000)
j = abs(((abs(x)/(pi/2))%4)-2)-1

w0 = 1000
k = 0.03
wd = k*w0
a = w0*x + wd*j
y = sin(a)
clk = y.>0
# plot(x,j,color="blue")
# plot(x,a,color="red")
# plot(x,y,color="green")

F = fft(clk)/(length(clk)/2)
plot(abs(F[900:1100]),color="blue")

j = -asin((abs(x)/(pi/2)-1))/(pi/2)

wd = k*w0
a = w0*x + wd*j
y = sin(a)
clk = y.>0

F = fft(clk)/(length(clk)/2)
plot(abs(F[900:1100]),color="green")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fe03f702810>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fe03efaecd0>

# %%
x = -pi:.00001:pi
# x = linspace(0,200,10000)
j = abs(((abs(x)/(pi/2))%4)-2)-1

w0 = 1000
k = 1
wd = k*w0
a = w0*x + wd*j
y = sin(a)
amp = 50
y = amp*sin(a)
clk = min(1, max(-1,y))
# plot(x,j,color="blue")
# plot(x,a,color="red")
# plot(x,y,color="green")

F = fft(clk)/(length(clk)/2)
plot(abs(F[1:10000]),color="blue")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fe034821f90>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fe034788d50>
